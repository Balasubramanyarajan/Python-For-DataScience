# %% [markdown]
# Importing Pandas

# %%
import pandas as pd

# %% [markdown]
# Example DataFrame

# %%
data = {
    'Name' : ['Alice', 'Bob', 'Charlie'],
    'Age' : [25, 30, 35],
    'Country' : ['USA', 'Canada', 'UK']
}
df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age Country
# 0    Alice   25     USA
# 1      Bob   30  Canada
# 2  Charlie   35      UK

# %% [markdown]
# Loading a DataFrame

# %%
df = pd.read_csv('orders.csv')

# %% [markdown]
# Exploring a Data Frame

# %%
df.head()  #First 5 rows
# Out:
#    OrderID   CustomerName       Product     Category  Quantity   Price  \
# 0     1001     John Smith        Laptop  Electronics         1  1200.0
# 1     1002      Sarah Lee    Headphones  Electronics         2   150.0
# 2     1003       Ali Khan  Office Chair    Furniture         1   300.0
# 3     1004     Alice Wong     Desk Lamp    Furniture         3    45.0
# 4     1005  Carlos Mendez      Keyboard  Electronics         2    80.0
#
#     OrderDate Shipped    Country
# 0  2024-06-01     Yes        USA
# 1  2024-06-03      No     Canada
# 2  2024-06-04     Yes        UAE
# 3  2024-06-05     Yes  Singapore
# 4  2024-06-06      No     Mexico

# %%
df.tail()   #Last 5 rows
# Out:
#     OrderID    CustomerName             Product     Category  Quantity  Price  \
# 35     1036   Emma Thompson  Desk Lamp with USB    Furniture         1   68.0
# 36     1037   Carlos Santos    Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri            Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim         Power Strip  Electronics         2   18.0
# 39     1040    Anna Ivanova          Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped      Country
# 35  2024-07-07      No           UK
# 36  2024-07-08     Yes     Portugal
# 37  2024-07-09     Yes         Iran
# 38  2024-07-10      No  South Korea
# 39  2024-07-11     Yes      Ukraine

# %%
df.info()   # Column types and non-null values
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   OrderID       40 non-null     int64
#  1   CustomerName  40 non-null     str
#  2   Product       40 non-null     str
#  3   Category      40 non-null     str
#  4   Quantity      40 non-null     int64
#  5   Price         40 non-null     float64
#  6   OrderDate     40 non-null     str
#  7   Shipped       40 non-null     str
#  8   Country       40 non-null     str
# dtypes: float64(1), int64(2), str(6)
# memory usage: 2.9 KB

# %%
df.describe()  # Summary stats
# Out:
#            OrderID    Quantity        Price
# count    40.000000   40.000000    40.000000
# mean   1020.500000    5.450000   106.457500
# std      11.690452   15.903475   201.091854
# min    1001.000000    1.000000     0.800000
# 25%    1010.750000    1.000000    18.000000
# 50%    1020.500000    1.000000    43.500000
# 75%    1030.250000    2.250000   112.500000
# max    1040.000000  100.000000  1200.000000

# %%
df.columns   # Column Names
# Out:
# Index(['OrderID', 'CustomerName', 'Product', 'Category', 'Quantity', 'Price',
#        'OrderDate', 'Shipped', 'Country'],
#       dtype='str')

# %%
df.index   #Row indices
# Out:
# RangeIndex(start=0, stop=40, step=1)

# %% [markdown]
# Accessing & Filtering Data

# %% [markdown]
# Basic Access

# %%
df['Product']   #Single Column
# Out:
# 0                    Laptop
# 1                Headphones
# 2              Office Chair
# 3                 Desk Lamp
# 4                  Keyboard
# 5                  Notebook
# 6             Standing Desk
# 7                   Monitor
# 8                       Pen
# 9                     Mouse
# 10                   Webcam
# 11             File Cabinet
# 12                  Stapler
# 13                USB Drive
# 14                Bookshelf
# 15            Printer Paper
# 16           Wireless Mouse
# 17           Desk Organizer
# 18               Calculator
# 19               Whiteboard
# 20             Highlighters
# 21        Bluetooth Speaker
# 22             Office Plant
# 23             Sticky Notes
# 24             Tablet Stand
# 25           Paper Shredder
# 26           Desk Chair Mat
# 27             Binder Clips
# 28        Wireless Keyboard
# 29            Desk Calendar
# 30                  USB Hub
# 31         Document Scanner
# 32    Desk Drawer Organizer
# ...

# %%
df[['CustomerName', 'Product']]   #Multiple Column
# Out:
#         CustomerName                Product
# 0         John Smith                 Laptop
# 1          Sarah Lee             Headphones
# 2           Ali Khan           Office Chair
# 3         Alice Wong              Desk Lamp
# 4      Carlos Mendez               Keyboard
# 5       Nora Ibrahim               Notebook
# 6        Emily Davis          Standing Desk
# 7         James Park                Monitor
# 8        Maria Rossi                    Pen
# 9   Takeshi Nakamura                  Mouse
# 10     Sophie Martin                 Webcam
# 11         Raj Patel           File Cabinet
# 12       Emma Wilson                Stapler
# 13   Diego Rodriguez              USB Drive
# 14         Lisa Chen              Bookshelf
# 15      Ahmed Hassan          Printer Paper
# 16     Anna Kowalski         Wireless Mouse
# 17     Michael Brown         Desk Organizer
# 18       Yuki Tanaka             Calculator
# 19   Fatima Al-Zahra             Whiteboard
# ...

# %%
df.iloc[0]   #First row by position
# Out:
# OrderID                1001
# CustomerName     John Smith
# Product              Laptop
# Category        Electronics
# Quantity                  1
# Price                1200.0
# OrderDate        2024-06-01
# Shipped                 Yes
# Country                 USA
# Name: 0, dtype: object

# %%
df.loc[df['CustomerName'] == 'John Smith']   #bring column by Customer Name
# Out:
#    OrderID CustomerName Product     Category  Quantity   Price   OrderDate  \
# 0     1001   John Smith  Laptop  Electronics         1  1200.0  2024-06-01
#
#   Shipped Country
# 0     Yes     USA

# %% [markdown]
# Conditional Filtering (Boolean masks)

# %%
df[df['Quantity']>5]   #Quantity over 5
# Out:
#     OrderID    CustomerName        Product    Category  Quantity  Price  \
# 8      1009     Maria Rossi            Pen  Stationery        10    1.5
# 15     1016    Ahmed Hassan  Printer Paper  Stationery        20    8.0
# 20     1021  David Thompson   Highlighters  Stationery         8    3.5
# 23     1024      Zara Ahmed   Sticky Notes  Stationery        15    4.0
# 27     1028     Nina Petrov   Binder Clips  Stationery        12    2.5
# 33     1034    Alex Johnson    Index Cards  Stationery       100    0.8
#
#      OrderDate Shipped   Country
# 8   2024-06-10     Yes     Italy
# 15  2024-06-17     Yes     Egypt
# 20  2024-06-22      No    Canada
# 23  2024-06-25      No  Pakistan
# 27  2024-06-29     Yes    Russia
# 33  2024-07-05     Yes       USA

# %%
df[df['Country'] == 'USA']   # Country Match
# Out:
#     OrderID   CustomerName         Product     Category  Quantity   Price  \
# 0      1001     John Smith          Laptop  Electronics         1  1200.0
# 17     1018  Michael Brown  Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100     0.8
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 17  2024-06-19      No     USA
# 33  2024-07-05     Yes     USA

# %%
df[(df['Quantity']==1) & (df['Country'] == 'UK')]   #Multiple Conditions
# Out:
#     OrderID   CustomerName             Product   Category  Quantity  Price  \
# 6      1007    Emily Davis       Standing Desk  Furniture         1  450.0
# 35     1036  Emma Thompson  Desk Lamp with USB  Furniture         1   68.0
#
#      OrderDate Shipped Country
# 6   2024-06-08     Yes      UK
# 35  2024-07-07      No      UK

# %% [markdown]
# Advanced Filtering

# %%
df[df['CustomerName'].str.startswith('A')]         # Names starting with A
# Out:
#     OrderID   CustomerName         Product     Category  Quantity  Price  \
# 2      1003       Ali Khan    Office Chair    Furniture         1  300.0
# 3      1004     Alice Wong       Desk Lamp    Furniture         3   45.0
# 15     1016   Ahmed Hassan   Printer Paper   Stationery        20    8.0
# 16     1017  Anna Kowalski  Wireless Mouse  Electronics         2   45.0
# 30     1031   Amira Hassan         USB Hub  Electronics         1   32.0
# 33     1034   Alex Johnson     Index Cards   Stationery       100    0.8
# 39     1040   Anna Ivanova      Desk Clock    Furniture         1   35.0
#
#      OrderDate Shipped    Country
# 2   2024-06-04     Yes        UAE
# 3   2024-06-05     Yes  Singapore
# 15  2024-06-17     Yes      Egypt
# 16  2024-06-18     Yes     Poland
# 30  2024-07-02     Yes    Morocco
# 33  2024-07-05     Yes        USA
# 39  2024-07-11     Yes    Ukraine

# %%
df[df['Country'].isin(['USA', 'UK'])]      # Match multiple values
# Out:
#     OrderID   CustomerName             Product     Category  Quantity   Price  \
# 0      1001     John Smith              Laptop  Electronics         1  1200.0
# 6      1007    Emily Davis       Standing Desk    Furniture         1   450.0
# 17     1018  Michael Brown      Desk Organizer    Furniture         1    65.0
# 33     1034   Alex Johnson         Index Cards   Stationery       100     0.8
# 35     1036  Emma Thompson  Desk Lamp with USB    Furniture         1    68.0
#
#      OrderDate Shipped Country
# 0   2024-06-01     Yes     USA
# 6   2024-06-08     Yes      UK
# 17  2024-06-19      No     USA
# 33  2024-07-05     Yes     USA
# 35  2024-07-07      No      UK

# %%
df[~df['Country'].isin(['USA'])]        # NOT condition
# Out:
#     OrderID      CustomerName                Product     Category  Quantity  \
# 1      1002         Sarah Lee             Headphones  Electronics         2
# 2      1003          Ali Khan           Office Chair    Furniture         1
# 3      1004        Alice Wong              Desk Lamp    Furniture         3
# 4      1005     Carlos Mendez               Keyboard  Electronics         2
# 5      1006      Nora Ibrahim               Notebook   Stationery         5
# 6      1007       Emily Davis          Standing Desk    Furniture         1
# 7      1008        James Park                Monitor  Electronics         2
# 8      1009       Maria Rossi                    Pen   Stationery        10
# 9      1010  Takeshi Nakamura                  Mouse  Electronics         1
# 10     1011     Sophie Martin                 Webcam  Electronics         1
# 11     1012         Raj Patel           File Cabinet    Furniture         2
# ...

# %% [markdown]
# CRUD Operations in pandas

# %% [markdown]
# Create (Insert Rows)

# %%
new_row = pd.DataFrame([{'OrderID' : 1041, 'CustomerName' : 'Bala', 'Product' : 'Webcam', 'Category' : 
                         'Electronics', 'Quantity' : 1, 'Price' : 150.0, 'OrderDate' : '2024-08-11', 'Shipped' : 'Yes', 'Country' : 'India'}])
df = pd.concat([df, new_row], ignore_index=True)

# %%
df.tail()
# Out:
#     OrderID    CustomerName           Product     Category  Quantity  Price  \
# 36     1037   Carlos Santos  Wireless Earbuds  Electronics         1  125.0
# 37     1038  Leila Mansouri          Desk Pad    Furniture         1   28.0
# 38     1039      Daniel Kim       Power Strip  Electronics         2   18.0
# 39     1040    Anna Ivanova        Desk Clock    Furniture         1   35.0
# 40     1041            Bala            Webcam  Electronics         1  300.0
#
#      OrderDate Shipped      Country
# 36  2024-07-08     Yes     PORTUGAL
# 37  2024-07-09     Yes         IRAN
# 38  2024-07-10      No  SOUTH KOREA
# 39  2024-07-11     Yes      UKRAINE
# 40  2024-08-11     Yes        INDIA

# %% [markdown]
# Read (Access Data)

# %%
df.loc[df['CustomerName'] == 'Bala']
# Out:
#     OrderID CustomerName Product     Category  Quantity  Price   OrderDate  \
# 40     1041         Bala  Webcam  Electronics         1  150.0  2024-08-11
#
#    Shipped Country
# 40     Yes   India

# %%
df.iloc[40]
# Out:
# OrderID                1041
# CustomerName           Bala
# Product              Webcam
# Category        Electronics
# Quantity                  1
# Price                 150.0
# OrderDate        2024-08-11
# Shipped                 Yes
# Country               India
# Name: 40, dtype: object

# %% [markdown]
# Update (Modify Values)

# %%
df.loc[df['CustomerName'] == 'Bala', 'Price'] = 300.0

# %%
df['Country'] = df['Country'].str.upper()

# %% [markdown]
# Delete (Drop Data)

# %%
df = df.drop(2, axis=0)                             # Drop row with index 2
df = df[df['Name'] != 'Alice']                      # Drop rows where name == Alice
df = df.drop('Age', axis=1)                         # Drop 'Age' column

# %% [markdown]
# Cleaning Data

# %%
df.isnull().sum()                          # Count missing values
df.dropna(inplace=True)                   # Drop rows with missing values
df.fillna({'Age': 0}, inplace=True)       # Fill missing Age values with 0
df.rename(columns={'Age': 'Years'}, inplace=True)   # Rename column
df['Years'] = df['Years'].astype(float)   # Convert column to float

# %% [markdown]
# Analysing Data

# %%
df['Country'].value_counts()                       # Count occurrences
df.groupby('Country')['Age'].mean()                # Average age per country
df.sort_values(by='Age', ascending=False)          # Sort by Age descending

# %% [markdown]
# Saving Data

# %%
df.to_csv('cleaned_data.csv', index=False)
df.to_excel('output.xlsx', index=False)
